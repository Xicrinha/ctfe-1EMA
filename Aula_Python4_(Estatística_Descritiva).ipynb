# %% [markdown]
# <a href="https://colab.research.google.com/github/Xicrinha/ctfe-1EMA/blob/main/Aula_Python4_(Estat%C3%ADstica_Descritiva).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exemplo - Estatística Descritiva**

# %%
A, B, C = input('').split()
# Out:
# 5.0 6.0 7.0

# %%
float(A)
float(B)
float(C)
A, B, C
# Out:
# ('5.0', '6.0', '7.0')

# %%
PA = 2
PB = 3
PC = 5

# %%
media = (PA*float(A) + PB*float(B) + PC*float(C))/(PA + PB + PC)
print(f'MEDIA = {media:.1f}')
# Out:
# MEDIA = 6.3

# %%
A, B, C = input('').split()
float(A)
float(B)
float(C)
A, B, C
PA = 2
PB = 3
PC= 5
media = (PA*float(A) + PB*float(B) + PC*float(C))/(PA + PB + PC)
print(f'MEDIA = {media:.1f}')
# Out:
# 5.0 6.0 7.0
# MEDIA = 6.3

# %% [markdown]
# # **Exemplo - Cálculo de variância e desvio padrão**

# %%
n1, n2, n3, n4 = input('insira os números da distribuição: ').split()
n1 = int(n1)
n2 = int(n2)
n3 = int(n3)
n4 = int(n4)
# Out:
# insira os números da distribuição 11 10 11 8

# %%
# Média
media = (n1 + n2 + n3 + n4)/4

# %%
# Desvios
d1 = n1 - media
d2 = n2 - media
d3 = n3 - media
d4 = n4 - media
d1, d2, d3, d4
# Out:
# (1.0, 0.0, 1.0, -2.0)

# %%
# Somatória do quadrado dos desvios
soma = d1**2 + d2**2 + d3**2 + d4**2
# Variância da distribuição
variancia = soma / 4
variancia
# Out:
# 1.5

# %%
# Desvio padrão
desvio_padrao = variancia**0.5
desvio_padrao
# Out:
# 1.224744871391589

# %%
# exemplo: 20 1 7 12
