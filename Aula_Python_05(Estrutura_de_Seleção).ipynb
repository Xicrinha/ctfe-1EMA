# %% [markdown]
# <a href="https://colab.research.google.com/github/Xicrinha/ctfe-1EMA/blob/main/Aula_Python_05(Estrutura_de_Sele%C3%A7%C3%A3o).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Estruturas de seleção:
# if
# elif
# else

# %%
# Operadores ------>
# == ----> igual
# != ----> diferente
# > , >= , < , <=

# %%
temperatura = float(input('Digite a temperatura: '))

if(temperatura > 30):
  print('Temperatura alta!!!!')
elif(temperatura > 20):
  print('Temperatura agradável :)')
else:
  print('Temperatura baixa :( ')
# Out:
# Digite a temperatura: 23
# Temperatura agradável :)
